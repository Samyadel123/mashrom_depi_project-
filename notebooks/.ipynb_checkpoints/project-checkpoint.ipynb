# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score
import joblib
import os

# %%
from ucimlrepo import fetch_ucirepo


def load_data():
    """Load the secondary mushroom dataset.

    Returns
    -------
    X : pandas.DataFrame
        Features.
    y : pandas.Series
        Target.
    """
    # fetch dataset
    secondary_mushroom = fetch_ucirepo(id=848)

    # data (as pandas dataframes)
    X = secondary_mushroom.data.features
    y = secondary_mushroom.data.targets  # Convert to Series if single column

    return X, y

# %%
X , y = load_data() 
X.shape
# Out:
# (61069, 20)

# %%
y.isnull().sum()
# Out:
# class    0
# dtype: int64

# %%
y.value_counts()['p'] + y.value_counts()['e']
# Out:
# np.int64(61069)

# %%
X.isnull().mean() * 100
# Out:
# cap-diameter             0.000000
# cap-shape                0.000000
# cap-surface             23.121387
# cap-color                0.000000
# does-bruise-or-bleed     0.000000
# gill-attachment         16.184971
# gill-spacing            41.040462
# gill-color               0.000000
# stem-height              0.000000
# stem-width               0.000000
# stem-root               84.393064
# stem-surface            62.427746
# stem-color               0.000000
# veil-type               94.797688
# veil-color              87.861272
# has-ring                 0.000000
# ring-type                4.046243
# spore-print-color       89.595376
# habitat                  0.000000
# season                   0.000000
# dtype: float64

# %%
df = X.copy()
df['class'] = y.copy()
df.head()
# Out:
#    cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0         15.26         x           g         o                    f
# 1         16.60         x           g         o                    f
# 2         14.07         x           g         o                    f
# 3         14.17         f           h         e                    f
# 4         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width  ...  \
# 0               e          NaN          w        16.95       17.09  ...
# 1               e          NaN          w        17.99       18.19  ...
# 2               e          NaN          w        17.80       17.74  ...
# 3               e          NaN          w        15.77       15.98  ...
# 4               e          NaN          w        16.53       17.20  ...
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0            y          w         u          w        t         g
# 1            y          w         u          w        t         g
# 2            y          w         u          w        t         g
# 3            y          w         u          w        t         p
# 4            y          w         u          w        t         p
#
#   spore-print-color habitat season class
# 0               NaN       d      w     p
# 1               NaN       d      u     p
# 2               NaN       d      w     p
# 3               NaN       d      w     p
# 4               NaN       d      w     p
#
# [5 rows x 21 columns]

# %%
n_p = df.isnull().mean() * 100

# %%
names = df.columns

# %%
# %%writefile src/util.py
def drop(null_data:pd.Series, percentage:float,names)->list[bool]:
    """
    Args:
        null_data : series of percentages of null values in the data
        percentage : allowed percentage in data
    output:   
        list of boolean -> tells you if this feature is with us or not (true = out)
    """
    return [names[i] for i in range(len(null_data)) if null_data[i]>percentage]
# Out:
# Writing src/util.py
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_ipython().run_cell_magic('writefile', 'src/util.py', 'def drop(null_data:pd.Series, percentage:float)->list[bool]:\n    """\n    Args:\n        null_data : series of percentages of null values in the data\n        percentage : allowed percentage in data\n    output:   \n        list of boolean -> tells you if this feature is with us or not (true = out)\n    """\n    return [names[i] for i in range(len(null_data)) if null_data[i]>percentage]\n')
#
# File ~\AppData\Local\uv\cache\archive-v0\Qc3EA2XshMVcxf10zBQP6\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Local\uv\cache\archive-v0\Qc3EA2XshMVcxf10zBQP6\Lib\site-packages\IPython\core\magics\osm.py:854, in OSMagics.writefile(self, line, cell)
#     851     print("Writing %s" % filename)
#     853 mode = 'a' if args.append else 'w'
# --> 854 with io.open(filename, mode, encoding='utf-8') as f:
#     855     f.write(cell)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'src/util.py'

# %%
to_drop = drop(null_data=n_p,percentage = 20.0 ,names = names)
to_drop,len(to_drop)
# Out:
# C:\Users\Samy Adel\AppData\Local\Temp\ipykernel_22692\2837835793.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return [names[i] for i in range(len(null_data)) if null_data[i]>percentage]
# (['cap-surface',
#   'gill-spacing',
#   'stem-root',
#   'stem-surface',
#   'veil-type',
#   'veil-color',
#   'spore-print-color'],
#  7)

# %%
df =

# %% [markdown]
# # plane
# - how would i approach this project?
# - i will start by making a split to the data (traing, validation, test)
# - then i will explore the train data
# - make a pipline of all the preprocessing steps
# - and based on my analysis i will choose the best features and the best model
# - i will use mlflow to track my experiments
# - i will make a api on my model using fastapi
# - i will dockerize my api
# - i will make a ci/cd pipeline using github actions

# %%
# step 1: split the data into training ,validation and testing sets
# 80% training , 10% validation and 10% testing
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.1, 
                                                  random_state=42, stratify=y)
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (24427, 20), y_train shape: (24427, 1)
# X_test shape: (6107, 20), y_test shape: (6107, 1)

# %% [markdown]
# now we log this data to start working on it

# %%
X_train.to_csv('../data/preprocessed/X_train.csv', index=False)
y_train.to_csv('../data/preprocessed/y_train.csv', index=False)
X_test.to_csv('../data/preprocessed/X_test.csv', index=False)
y_test.to_csv('../data/preprocessed/y_test.csv', index=False)

# %% [markdown]
# # phase 1 : data exploration and preprocessing

# %%
X_train = pd.read_csv("../data/preprocessed/X_train.csv")
y_train = pd.read_csv("../data/preprocessed/y_train.csv")
X_test = pd.read_csv("../data/preprocessed/X_test.csv")
y_test = pd.read_csv("../data/preprocessed/y_test.csv")

# %%
X_train.head()
# Out:
#    cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0          8.66         x           s         w                    f
# 1          6.19         x           y         w                    f
# 2          6.46         x           h         g                    f
# 3          3.45         x           h         n                    f
# 4         10.11         o         NaN         n                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0               s            c          w         6.87       28.99       NaN
# 1               e            c          p         4.14       12.74       NaN
# 2               a            d          n         6.81        5.33       NaN
# 3             NaN            c          k         6.09        7.00       NaN
# 4               f            f          f         3.89       25.93       NaN
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0          NaN          w       NaN        NaN        f         f
# 1          NaN          w       NaN          w        t         e
# 2            t          w       NaN        NaN        t         l
# 3            s          w       NaN          w        f         f
# 4            g          n       NaN        NaN        f         f
#
#   spore-print-color habitat season
# 0               NaN       m      s
# 1               NaN       m      u
# 2               NaN       d      u
# 3                 k       d      a
# 4               NaN       d      u

# %%
# now we want to explore the data 
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24427 entries, 0 to 24426
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cap-diameter          24427 non-null  float64
#  1   cap-shape             24427 non-null  object
#  2   cap-surface           18791 non-null  object
#  3   cap-color             24427 non-null  object
#  4   does-bruise-or-bleed  24427 non-null  object
#  5   gill-attachment       20506 non-null  object
#  6   gill-spacing          14326 non-null  object
#  7   gill-color            24427 non-null  object
#  8   stem-height           24427 non-null  float64
#  9   stem-width            24427 non-null  float64
#  10  stem-root             3744 non-null   object
#  11  stem-surface          9202 non-null   object
#  12  stem-color            24427 non-null  object
#  13  veil-type             1281 non-null   object
#  14  veil-color            3034 non-null   object
#  15  has-ring              24427 non-null  object
#  16  ring-type             23475 non-null  object
#  17  spore-print-color     2577 non-null   object
#  18  habitat               24427 non-null  object
#  19  season                24427 non-null  object
# dtypes: float64(3), object(17)
# memory usage: 3.7+ MB

# %% [markdown]
# to start our investigation we split the data into numrical and categorical features and start doing (Univariate, Bivariate, Multivariate) analysis on the data

# %%
X_train.isnull().sum() / len(X_train) * 100
# Out:
# cap-diameter             0.000000
# cap-shape                0.000000
# cap-surface             23.072829
# cap-color                0.000000
# does-bruise-or-bleed     0.000000
# gill-attachment         16.051910
# gill-spacing            41.351783
# gill-color               0.000000
# stem-height              0.000000
# stem-width               0.000000
# stem-root               84.672698
# stem-surface            62.328571
# stem-color               0.000000
# veil-type               94.755803
# veil-color              87.579318
# has-ring                 0.000000
# ring-type                3.897327
# spore-print-color       89.450199
# habitat                  0.000000
# season                   0.000000
# dtype: float64

# %%
# split the data into categorical and numerical features
categorical_features = X_train.select_dtypes(include=['object'])
numerical_features = X_train.select_dtypes(include=['int64', 'float64'])
categorical_features.shape, numerical_features.shape
# Out:
# ((36641, 17), (36641, 3))

# %% [markdown]
# ### nurmical features analysis

# %%
numerical_features.describe()
# Out:
#        cap-diameter   stem-height    stem-width
# count  36641.000000  36641.000000  36641.000000
# mean       6.730906      6.576055     12.139014
# std        5.257113      3.344902     10.044600
# min        0.440000      0.000000      0.000000
# 25%        3.490000      4.630000      5.250000
# 50%        5.860000      5.950000     10.150000
# 75%        8.520000      7.730000     16.510000
# max       59.460000     32.430000    103.910000

# %%
corr = numerical_features.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
for i in range(len(numerical_features.columns)):
    for j in range(i+1, len(numerical_features.columns)):
        plt.figure(figsize=(6, 6))
        sns.jointplot(x=numerical_features.columns[i], y=numerical_features.columns[j], data=numerical_features, hue=y_train['class'], kind='scatter')
        plt.suptitle(f'Joint plot of {numerical_features.columns[i]} and {numerical_features.columns[j]} by Target Class', y=1.02)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## for the categorical features

# %%
categorical_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36641 entries, 0 to 36640
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cap-shape             36641 non-null  object
#  1   cap-surface           28225 non-null  object
#  2   cap-color             36641 non-null  object
#  3   does-bruise-or-bleed  36641 non-null  object
#  4   gill-attachment       30784 non-null  object
#  5   gill-spacing          21558 non-null  object
#  6   gill-color            36641 non-null  object
#  7   stem-root             5642 non-null   object
#  8   stem-surface          13759 non-null  object
#  9   stem-color            36641 non-null  object
#  10  veil-type             1937 non-null   object
#  11  veil-color            4501 non-null   object
#  12  has-ring              36641 non-null  object
#  13  ring-type             35194 non-null  object
#  14  spore-print-color     3844 non-null   object
#  15  habitat               36641 non-null  object
#  16  season                36641 non-null  object
# dtypes: object(17)
# memory usage: 4.8+ MB

# %%
categorical_features.isnull().sum()
# Out:
# cap-shape                   0
# cap-surface              8416
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          5857
# gill-spacing            15083
# gill-color                  0
# stem-root               30999
# stem-surface            22882
# stem-color                  0
# veil-type               34704
# veil-color              32140
# has-ring                    0
# ring-type                1447
# spore-print-color       32797
# habitat                     0
# season                      0
# dtype: int64

# %%
categorical_features.duplicated().sum()
# Out:
# np.int64(31747)

# %%
# duplicated percentage in data
categorical_features.duplicated().sum() / len(categorical_features) * 100
# Out:
# np.float64(86.64337763707323)
